# %% [markdown]
# # Care Companion Test Patient Notebook
#
# In this notebook we will be testing the NLP engine of the application by importing a test patient and print the output of what the LLM has organized for the patient.

# %%
sample_patient_input = """
    My lower back has been hurting for about 3 weeks now. It's worse in the morning when I wake up. 
    I tried taking Advil 200mg once in a while but it doesn't do much. I'm worried it might be a slipped disc 
    because I started lifting weights again. Should I get an MRI or do physical therapy?
    """

# %%
print("--- PRE-VISIT AGENDA ---")
pre_visit = generate_pre_visit_agenda(sample_patient_input)
print(json.dumps(pre_visit, indent=2))

# %%
sample_doctor_notes = """
    Patient presents with mechanical lumbar spine strain. Lumbar flexion mildly limited.
    Rx: Naproxen 500mg PO BID with food for 10 days. Cyclobenzaprine 5mg PO QHS PRN muscle spasms.
    Plan: Refer to outpatient Physical Therapy 2x/week for 4 weeks. No heavy lifting >15 lbs.
    Return to clinic in 4 weeks if no improvement. Go to ED immediately if urinary retention or lower extremity numbness develops.
    """

# %%
print("\n--- POST-VISIT ACTION PLAN ---")
post_visit = generate_post_visit_actions(sample_doctor_notes)
print(json.dumps(post_visit, indent=2))
